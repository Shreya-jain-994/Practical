# %% [markdown]
# # **Practical No: 8**
#
# **AIM:** Air Quality Index

# %% [markdown]
# **CODE and OUTPUT:**

# %%
# importing pandas module for data frame
import pandas as pd
 
# loading dataset and storing in train variable
train=pd.read_csv('/content/AQI.csv')
 
# display top 5 data
train.head()
# Out:
#    PM2.5-AVG  PM210-AVG  NO2-AVG  NH3-AVG  SO2-AG  CO  OZONE-AVG  \
# 0        190        131      107        4      42   0         63
# 1        188        131      110        4      40   0         62
# 2        280        174      155        2      37   0         52
# 3        302        181      144        2      39   0         78
# 4        285        160      121        3      19   0         71
#
#    air_quality_index
# 0                190
# 1                188
# 2                280
# 3                302
# 4                285

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PM2.5-AVG          10 non-null     int64
#  1   PM210-AVG          10 non-null     int64
#  2   NO2-AVG            10 non-null     int64
#  3   NH3-AVG            10 non-null     int64
#  4   SO2-AG             10 non-null     int64
#  5   CO                 10 non-null     int64
#  6   OZONE-AVG          10 non-null     int64
#  7   air_quality_index  10 non-null     int64
# dtypes: int64(8)
# memory usage: 768.0 bytes

# %%
train['PM2.5-AVG'].hist()

# %%
# importing Randomforest
from sklearn.ensemble import RandomForestRegressor

# %%
# creating model
m1 = RandomForestRegressor()
 
# separating class label and other attributes
train1 = train.drop(['air_quality_index'], axis=1)
target = train['air_quality_index']
 
# Fitting the model
m1.fit(train1, target)
# Out:
# RandomForestRegressor()

# %%
# calculating the score and the score is  98%
m1.score(train1, target) * 100
# Out:
# 98.33732789153046

# %%
# predicting the model with other values (testing the data)
# so AQI is 106.03

m1.predict([[123, 45, 67, 34, 5, 0, 23]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# array([103.87])

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
# Adaboost model
# importing module
 
# defining model
m2 = AdaBoostRegressor()
 
# Fitting the model
m2.fit(train1, target)
# Out:
# AdaBoostRegressor()

# %%
# calculating the score and the score is  100%
m2.score(train1, target)*100
# Out:
# 99.95418500857122

# %%
# predicting the model with other values (testing the data)
# so AQI is 123

m2.predict([[123, 45, 67, 34, 5, 0, 23]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# array([115.])
